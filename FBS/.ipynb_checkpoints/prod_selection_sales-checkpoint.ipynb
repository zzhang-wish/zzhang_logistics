# %%
from wishpy.dataworker import DataWorker
dw = DataWorker(google_secret='../wishpy/client_secret.json')

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pdb
import datetime
from scipy import stats
import FBS as fbs
import seaborn as sns

# %matplotlib inline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/wishpy/dataworker.py:83: UserWarning: [Errno 2] No such file or directory: '../wishpy/client_secret.json'
#   warnings.warn(str(e))

# %%
df_score = dw.td_query(engine='hive' , job_id=624460220)
df_score.head(10)
# Out:
# You can look at job id 624460220
#                  product_id  true_price  product_rating  overall_gmv_score  \
# 0  51312590d695e310c4dca5f7   57.000000             NaN           0.000000
# 1  513125ec2700980df5eb460f   19.559879             NaN           0.000098
# 2  5131263fd695e310bf008b74   35.082065             NaN           0.000105
# 3  51549f9e77232a55c4ffd588   23.000000             5.0           0.000000
# 4  5154a506d33f971cc03b7422   22.670000             5.0           0.000132
# 5  5182b4ea9a222b494fe5d855   30.183843             3.0           0.000143
# 6  5182b56e9a222b494cf439ea         NaN             NaN           0.000000
# 7  5182be289a222b498382dec9   25.000000             NaN           0.000000
# 8  51c8693065cfdb0b040cfee3    8.720000             NaN           0.000032
# 9  51ce185865cfdb528a963c06   34.000000             NaN           0.000000
#
#    recent_gmv_score  lower_bound_rating  product_refund_ratio  positive_ratio  \
# ...

# %%
df_store = dw.td_query(engine='hive' , job_id=624826043)
df_store.head(10)
# Out:
# You can look at job id 624826043
#   country state        city                product_id  \
# 0      US    VA   Arlington  5c17e1a57acb532571fa2a64
# 1      US    VA   Arlington  5c17e1a58a8cad21e24f5434
# 2      US    VA   Arlington  5c17e1a58fa64a224ae2a5d9
# 3      US    VA   Arlington  5c17e1a58fa64a224ae2a5d9
# 4      US    VA   Arlington  5c17e1a58fa64a224ae2a5d9
# 5      US    VA   Arlington  5c17e1b2d2583b21e0fd169e
# 6      US    VA   Arlington  5c17e1b2d2583b21e0fd169e
# 7      US    VA   Arlington  5c17e1b2f2d15e222f99ab06
# 8      US    VA   Arlington  5c17e1b2f2d15e222f99ab06
# 9      US    VA   Arlington  5c17e1b3c28a882220a93298
#
#                variation_id  fbs_inv  blue_inv  blue_sales  fbs_sales  \
# 0  5c17e1a57acb532571fa2a65        0         1           0          0
# 1  5c3d959d1076b7456a631a59        0         3           0          0
# 2  5c256bfdf8fd42220fcb86bf        0         3           0          0
# ...

# %%
df_join = df_store.merge(df_score, how='left', on='product_id')
df_join.head(5)
# Out:
#   country state        city                product_id  \
# 0      US    VA   Arlington  5c17e1a57acb532571fa2a64
# 1      US    VA   Arlington  5c17e1a58a8cad21e24f5434
# 2      US    VA   Arlington  5c17e1a58fa64a224ae2a5d9
# 3      US    VA   Arlington  5c17e1a58fa64a224ae2a5d9
# 4      US    VA   Arlington  5c17e1a58fa64a224ae2a5d9
#
#                variation_id  fbs_inv  blue_inv  blue_sales  fbs_sales  \
# 0  5c17e1a57acb532571fa2a65        0         1           0          0
# 1  5c3d959d1076b7456a631a59        0         3           0          0
# 2  5c256bfdf8fd42220fcb86bf        0         3           0          0
# 3  5c256bfef8fd42220fcb86c1        0         3           0          0
# 4  5c256bfff8fd42220fcb86c3        0         2           0          0
#
#    is_blue_sales  ...  store_count  region_rank  true_price  product_rating  \
# 0              0  ...          NaN          NaN         NaN             NaN
# ...

# %%
df_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 160954 entries, 0 to 160953
# Data columns (total 22 columns):
# country                 160954 non-null object
# state                   160954 non-null object
# city                    160954 non-null object
# product_id              160954 non-null object
# variation_id            160954 non-null object
# fbs_inv                 160954 non-null int64
# blue_inv                160954 non-null int64
# blue_sales              160954 non-null int64
# fbs_sales               160954 non-null int64
# is_blue_sales           160954 non-null int64
# is_fbs_sales            160954 non-null int64
# merch_sales             23620 non-null float64
# store_count             23620 non-null float64
# region_rank             23620 non-null float64
# true_price              946 non-null float64
# product_rating          944 non-null float64
# overall_gmv_score       946 non-null float64
# recent_gmv_score        946 non-null float64
# ...

# %% [markdown]
# # FBS data preparation

# %%
mask1 = df_join.fbs_inv>0
mask2 = df_join.blue_inv==0

mask3 = df_join.merch_sales.notnull()
mask4 = df_join.score.notnull()

mask5 = df_join.fbs_inv==0
mask6 = df_join.blue_inv>0

mask7 = df_join.fbs_sales >0
mask8 = df_join.blue_sales >0


df_fbs = df_join.loc[mask1 & mask2 & mask3,:]
#df_fbs[['merch_sales','store_count','region_rank']] = df_fbs[['merch_sales','store_count','region_rank']].fillna(0)
# df_fbs = df_raw.loc[df_raw.region_rank.notnull(),:]

df_fbs.head()
# Out:
#     country state   city                product_id              variation_id  \
# 480      US    OH  Akron  53fc3a421c105e749dcc683e  53fc3a421c105e749dcc6840
# 481      US    OH  Akron  53fc3a421c105e749dcc683e  53fc3a421c105e749dcc6840
# 482      US  Ohio  Akron  53fc3a421c105e749dcc683e  53fc3a421c105e749dcc6840
# 483      US  Ohio  Akron  53fc3a421c105e749dcc683e  53fc3a421c105e749dcc6840
# 485      US    OH  Akron  54744d9c90c7763887d7f893  5aa35aa64f6b491dcf1f96d5
#
#      fbs_inv  blue_inv  blue_sales  fbs_sales  is_blue_sales  ...  \
# 480        2         0           0          0              0  ...
# 481        2         0           0          0              0  ...
# 482        2         0           0          0              0  ...
# 483        2         0           0          0              0  ...
# 485        2         0           0          0              0  ...
#
#      store_count  region_rank  true_price  product_rating  overall_gmv_score  \
# ...

# %%
print("There are %i FBS exclusive vid has inventory, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask1 & mask2,:].shape[0])
print("There are %i Blue exclusive vid has inventory, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask5 & mask6,:].shape[0])
print('-'*100)
print("There are %i FBS exclusive vid has merch sales, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask1 & mask2 & mask3,:].shape[0])
print("There are %i Blue exclusive vid has merch sales, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask5 & mask6 & mask3,:].shape[0])
print('-'*100)
print("There are %i FBS vid has been sold, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask1 & mask7,:].shape[0])
print("There are %i Blue vid has been sold, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask5 & mask8,:].shape[0])
print('-'*100)
print("There are total %i vid has inventory, from '2019-11-18' to '2019-11-24'" %df_join.shape[0])
print('-'*100)
print("There are total %i vid has relevancy score, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask4,:].shape[0])
print('-'*100)
print("There are %i FBS exclusive vid has relevancy score, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask1 & mask2 & mask4,:].shape[0])
print("There are %i Blue exclusive vid has relevancy score, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask5 & mask6 & mask4,:].shape[0])
print('-'*100)
print("There are %i FBS vid has relevancy score, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask1 & mask4,:].shape[0])
print("There are %i blue vid has relevancy score, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask6 & mask4,:].shape[0])
print('-'*100)
print("There are %i FBS exclusive vid has both relevancy score and merch sales, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask1 & mask2 & mask3 & mask4,:].shape[0])
print("There are %i Blue exclusive vid has both relevancy score and merch sales, from '2019-11-18' to '2019-11-24'" %df_join.loc[mask5 & mask6 & mask3 & mask4,:].shape[0])
print('-'*100)
# Out:
# There are 31865 FBS exclusive vid has inventory, from '2019-11-18' to '2019-11-24'
# There are 128842 Blue exclusive vid has inventory, from '2019-11-18' to '2019-11-24'
# ----------------------------------------------------------------------------------------------------
# There are 21030 FBS exclusive vid has merch sales, from '2019-11-18' to '2019-11-24'
# There are 2395 Blue exclusive vid has merch sales, from '2019-11-18' to '2019-11-24'
# ----------------------------------------------------------------------------------------------------
# There are 2249 FBS vid has been sold, from '2019-11-18' to '2019-11-24'
# There are 19538 Blue vid has been sold, from '2019-11-18' to '2019-11-24'
# ----------------------------------------------------------------------------------------------------
# There are total 160954 vid has inventory, from '2019-11-18' to '2019-11-24'
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Correlation between whether there is sale and prod region sales ranking

# %%
plt.figure()
plt.figure(figsize=(15,10))
plt.xlabel("region_rank")
plt.ylabel("is_fbs_sales")
plt.scatter(y=df_fbs.is_fbs_sales, x=df_fbs.region_rank, alpha=0.4, s=df_fbs.store_count**1.6)
plt.show()

# %%
np.corrcoef(x=df_fbs.is_fbs_sales, y=df_fbs.region_rank)
# Out:
# array([[ 1.        , -0.12385969],
#        [-0.12385969,  1.        ]])

# %% [markdown]
# ### H0:There is no statistically significant relationship between region_rank and whether this is a fbs store sales

# %%
chi2, p, dof, ex = stats.chi2_contingency([df_fbs.region_rank,df_fbs.is_fbs_sales], correction=False)
chi2, p, dof
# Out:
# (244792.78102620074, 0.0, 21029)

# %% [markdown]
# ## correlation between store sales sum and prod region sales rank

# %%
plt.figure()
plt.figure(figsize=(15,10))
plt.xlabel("region_rank")
plt.ylabel("fbs_sales")
plt.scatter(y=df_fbs[df_fbs.fbs_sales>0].fbs_sales, x=df_fbs[df_fbs.fbs_sales>0].region_rank, alpha=0.3, s=df_fbs.store_count**1.6)
plt.show()

# %%
np.corrcoef(y=df_fbs[df_fbs.fbs_sales>0].fbs_sales, x=df_fbs[df_fbs.fbs_sales>0].region_rank)
# Out:
# array([[ 1.        , -0.26363356],
#        [-0.26363356,  1.        ]])

# %% [markdown]
# ### H0:There is no statistically significant relationship between region_rank and whether this is a fbs store sales

# %%
chi2, p, dof, ex = stats.chi2_contingency([df_fbs[df_fbs.fbs_sales>0].fbs_sales,df_fbs[df_fbs.fbs_sales>0].region_rank], correction=False)
chi2, p, dof
# Out:
# (60272.932170459106, 0.0, 1548)

# %% [markdown]
# ## correlation on all features, overall

# %%
df_join.columns
# Out:
# Index(['country', 'state', 'city', 'product_id', 'variation_id', 'fbs_inv',
#        'blue_inv', 'blue_sales', 'fbs_sales', 'is_blue_sales', 'is_fbs_sales',
#        'merch_sales', 'store_count', 'region_rank', 'true_price',
#        'product_rating', 'overall_gmv_score', 'recent_gmv_score',
#        'lower_bound_rating', 'product_refund_ratio', 'positive_ratio',
#        'score'],
#       dtype='object')

# %%
pd.plotting.scatter_matrix(df_join[['store_count','region_rank','true_price','product_rating','overall_gmv_score','recent_gmv_score','lower_bound_rating'
                    ,'product_refund_ratio','positive_ratio','score','fbs_sales']], figsize=(20, 20))
plt.show()

# %%
#sns.pairplot(df_join[['store_count','region_rank','true_price','product_rating','overall_gmv_score','recent_gmv_score','lower_bound_rating','product_refund_ratio','positive_ratio','score','fbs_sales','blue_sales']])

# %% [markdown]
# # Blue data

# %%
df_raw.head()
# Out:
#   country  state   city                product_id              variation_id  \
# 0      US  Texas  77009  5c09f46024d662465f5d25fb  5c09f46024d662465f5d25fc
# 1      US  Texas  77009  5c359f1eb8115c26bd1b936b  5c359f1eb8115c26bd1b936c
# 2      US  Texas  77009  5c359f1eb8115c26bd1b936b  5c359f2fcdbd063c16534229
# 3      US  Texas  77009  5c4a02d05ac58a26b94baa4b  5c4a03178b26e56dcf17a534
# 4      US  Texas  77009  5c4a02d05ac58a26b94baa4b  5c4a032552631e2672b8eff4
#
#    fbs_inv  blue_inv  blue_sales  fbs_sales  is_blue_sales  is_fbs_sales  \
# 0        0         5           0          0              0             0
# 1        0         3           0          0              0             0
# 2        0         3           0          0              0             0
# 3        0         3           0          0              0             0
# 4        0         3           0          0              0             0
#
#    merch_sales  store_count  region_rank
# ...

# %%
df_blue = df_raw.loc[(df_raw.blue_inv>0) & (df_raw.fbs_inv==0),:]
#df_fbs[['merch_sales','store_count','region_rank']] = df_fbs[['merch_sales','store_count','region_rank']].fillna(0)
df_blue = df_raw.loc[df_raw.region_rank.notnull(),:]
df_blue.head()
# Out:
#     country state   city                product_id              variation_id  \
# 361      US    SC  Aiken  5c4a0322772235268e395f24  5c4a0342f7fd2c269d84f58e
# 362      US    SC  Aiken  5c4a0322772235268e395f24  5c4a0342f7fd2c269d84f58e
# 576      US  Ohio  Akron  5d1573076ee9c268adf3bf85  5d1573366ee9c268adf3c168
# 577      US  Ohio  Akron  5d1573076ee9c268adf3bf85  5d1573366ee9c268adf3c168
# 578      US    OH  Akron  5d1573076ee9c268adf3bf85  5d1573366ee9c268adf3c168
#
#      fbs_inv  blue_inv  blue_sales  fbs_sales  is_blue_sales  is_fbs_sales  \
# 361        0         2           0          0              0             0
# 362        0         2           0          0              0             0
# 576        0         3           0          0              0             0
# 577        0         3           0          0              0             0
# 578        0         1           0          0              0             0
#
#      merch_sales  store_count  region_rank
# ...

# %%
df_blue.shape[0], df_raw.shape[0], str(round(100*df_fbs.shape[0]/df_raw.shape[0],1))+'%'
# Out:
# (11405, 136489, '91.4%')

# %% [markdown]
# ## correlation between store sales sum and prod region sales rank

# %%
plt.figure()
plt.figure(figsize=(15,10))
plt.xlabel("region_rank")
plt.ylabel("is_blue_sales")
plt.scatter(y=df_blue.is_blue_sales, x=df_blue.region_rank, alpha=0.4, s=df_blue.store_count**1.6)
plt.show()

# %%
np.corrcoef(x=df_blue.is_blue_sales, y=df_blue.region_rank)
# Out:
# array([[ 1.       , -0.1321781],
#        [-0.1321781,  1.       ]])

# %%
chi2, p, dof, ex = stats.chi2_contingency([df_blue.region_rank,df_blue.is_blue_sales], correction=False)
chi2, p, dof
# Out:
# (98029.42156953021, 0.0, 11404)

# %% [markdown]
# ## correlation between store sales sum and prod region sales rank

# %%
plt.figure()
plt.figure(figsize=(15,10))
plt.xlabel("region_rank")
plt.ylabel("blue_sales")
plt.scatter(y=df_blue[df_blue.blue_sales>0].blue_sales, x=df_blue[df_blue.blue_sales>0].region_rank, alpha=0.3, s=df_blue.store_count**2)
plt.show()

# %%
np.corrcoef(y=df_blue[df_blue.blue_sales>0].blue_sales, x=df_blue[df_blue.blue_sales>0].region_rank)
# Out:
# array([[ 1.        , -0.15207518],
#        [-0.15207518,  1.        ]])

# %%
chi2, p, dof, ex = stats.chi2_contingency([df_blue[df_blue.blue_sales>0].blue_sales,df_blue[df_blue.blue_sales>0].region_rank], correction=False)
chi2, p, dof
# Out:
# (23811.316751159364, 0.0, 545)
